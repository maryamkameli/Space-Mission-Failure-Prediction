# %%
import numpy as np
import pandas as pd

# %%
sm = pd.read_csv('SpaceMissions.csv')
print(sm.shape)
print(list(sc.columns)) 
print(sm.info())   
sm.head()
# Out:
# (150, 18)
# ['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum', 'Detail', 'Status Rocket', ' Rocket', 'Status Mission']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Company                150 non-null    object
#  1   Launch Date            150 non-null    object
#  2   Launch Time            146 non-null    object
#  3   Launch Site            150 non-null    object
#  4   Temperature (° F)      136 non-null    float64
#  5   Wind speed (MPH)       136 non-null    float64
#  6   Humidity (%)           136 non-null    float64
#  7   Vehicle Type           150 non-null    object
#  8   Liftoff Thrust (kN)    150 non-null    int64
#  9   Payload to Orbit (kg)  150 non-null    int64
#  10  Rocket Height (m)      150 non-null    float64
#  11  Fairing Diameter (m)   146 non-null    float64
# ...

# %%
# some imports to set up plotting 
import matplotlib.pyplot as plt
# pip install seaborn 
import seaborn as sns
# Graphics in retina format are sharper and more legible
# %config InlineBackend.figure_format = 'retina'

# %%
print(list(sc.columns))
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum', 'Detail', 'Status Rocket', ' Rocket', 'Status Mission']

# %%
sc['Status Mission'] = sc['Status Mission'].astype(str)
sns.countplot(x='Company Name', hue='Status Mission', data=sc);

# %%
print(list(sm.columns))
# Out:
# ['Company', 'Launch Date', 'Launch Time', 'Launch Site', 'Temperature (° F)', 'Wind speed (MPH)', 'Humidity (%)', 'Vehicle Type', 'Liftoff Thrust (kN)', 'Payload to Orbit (kg)', 'Rocket Height (m)', 'Fairing Diameter (m)', 'Payload Name', 'Payload Type', 'Payload Mass (kg)', 'Payload Orbit', 'Mission Status', 'Failure Reason']

# %%
# plt.figure(figsize=(15,8))
sns.set(font_scale=0.3)
sm['Mission Status'] = sm['Mission Status'].astype(str)
sns_plot = sns.countplot(x='Company', hue='Mission Status', data=sm);
fig = plt.savefig('res.png')

# %%
sc = pd.read_csv('Space_Corrected.csv')
print(sc.shape)
print(list(sc.columns)) 
print(sc.info())   
sc.head()
# Out:
# (4324, 9)
# ['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum', 'Detail', 'Status Rocket', ' Rocket', 'Status Mission']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    4324 non-null   int64
#  1   Unnamed: 0      4324 non-null   int64
#  2   Company Name    4324 non-null   object
#  3   Location        4324 non-null   object
#  4   Datum           4324 non-null   object
#  5   Detail          4324 non-null   object
#  6   Status Rocket   4324 non-null   object
#  7    Rocket         964 non-null    object
#  8   Status Mission  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB
# None
#    Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# ...

# %%
sm.describe()
# Out:
#        Temperature (° F)  Wind speed (MPH)  Humidity (%)  Liftoff Thrust (kN)  \
# count         136.000000        136.000000    136.000000           150.000000
# mean           70.441176          8.007353     76.066176          5668.360000
# std            12.700986          4.968786     15.708079          3619.496024
# min            37.000000          0.000000     37.000000           343.000000
# 25%            60.750000          5.000000     65.000000          3511.000000
# 50%            73.000000          8.000000     78.000000          5885.000000
# 75%            80.000000         12.000000     89.000000          6804.000000
# max            93.000000         23.000000    100.000000         22819.000000
#
#        Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)
# count             150.000000         150.000000            146.000000
# mean            10708.913333          56.337133              4.252329
# ...

# %%
sc.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0
# count   4324.000000  4324.000000
# mean    2161.500000  2161.500000
# std     1248.375611  1248.375611
# min        0.000000     0.000000
# 25%     1080.750000  1080.750000
# 50%     2161.500000  2161.500000
# 75%     3242.250000  3242.250000
# max     4323.000000  4323.000000

# %%
sm['Mission Status'].value_counts()
# Out:
# Mission Status
# Success    120
# Failure     30
# Name: count, dtype: int64

# %%
sc['Status Mission'].value_counts()
# Out:
# Status Mission
# Success              3879
# Failure               339
# Partial Failure       102
# Prelaunch Failure       4
# Name: count, dtype: int64

# %%
columns_to_show = ['Location']

sc.groupby(['Status Mission'])[columns_to_show].describe(percentiles=[])
# Out:
#                   Location         \
#                      count unique
# Status Mission
# Failure                339     90
# Partial Failure        102     45
# Prelaunch Failure        4      4
# Success               3879    128
#
#
#                                                                  top freq
# Status Mission
# Failure                    Site 1/5, Baikonur Cosmodrome, Kazakhstan   32
# Partial Failure           Site 31/6, Baikonur Cosmodrome, Kazakhstan    6
# Prelaunch Failure  Imam Khomeini Spaceport, Semnan Space Center, ...    1
# Success                   Site 31/6, Baikonur Cosmodrome, Kazakhstan  220

# %%
columns_to_show = ['Company Name']

sc.groupby(['Status Mission'])[columns_to_show].describe(percentiles=[])
# Out:
#                   Company Name
#                          count unique        top  freq
# Status Mission
# Failure                    339     43  RVSN USSR   121
# Partial Failure            102     23  RVSN USSR    41
# Prelaunch Failure            4      4        ISA     1
# Success                   3879     49  RVSN USSR  1614

# %%
print(list(sc.columns))
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum', 'Detail', 'Status Rocket', ' Rocket', 'Status Mission']

# %%
crss_arr = pd.crosstab(sc['Status Mission']=='Success', sc['Company Name']=='RVSN USSR')
print(crss_arr)
crss_arr = crss_arr.values
precision = crss_arr[0,0]/np.sum(crss_arr[0,:])
recall = crss_arr[0,0]/np.sum(crss_arr[:,0])
accuracy = np.sum(crss_arr[0,0]+crss_arr[1,1])/np.sum(crss_arr)

print("precision=",precision)
print("recall=",recall)
print("accuracy=",accuracy)
# Out:
# Company Name    False  True
# Status Mission
# False             282    163
# True             2265   1614
# precision= 0.6337078651685393
# recall= 0.11071849234393404
# accuracy= 0.43848288621646625

# %%
pd.crosstab(sc['Status Mission']=='Success', sc['Company Name']=='RVSN USSR')
# Out:
# Company Name    False  True
# Status Mission
# False             282    163
# True             2265   1614

# %%
pd.crosstab(sc['Location'],sc['Status Mission'])
# Out:
# Status Mission                                      Failure  Partial Failure  \
# Location
# Blue Origin Launch Site, West Texas, Texas, USA           0                0
# Brigitte, Hammaguir, Algeria, France                      0                1
# Cosmic Girl, Mojave Air and Space Port, Califor...        1                0
# Douglas F4D Skyray, Naval Air Station Point Mug...        6                0
# ELA-1, Guiana Space Centre, French Guiana, France         3                0
# ...                                                     ...              ...
# Taiyuan Satellite Launch Center, China                    2                0
# Uchinoura Space Center, Japan                             5                0
# VLS Pad, Alc?›ntara Launch Center, Maranh?œo, B...        2                0
# Vertical Launch Area, Spaceport America, New Me...        1                3
# Xichang Satellite Launch Center, China                    0                0
#
# ...
